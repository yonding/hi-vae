# %%
# IMPORT MODULES #
import itertools
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler

# %%
# VARIABLES #
max_remove_count=2

# %%
# COMPLETE DATA #
wine = load_wine()

X_df = pd.DataFrame(wine.data, columns=wine.feature_names)
y_df = pd.DataFrame(wine.target, columns=["target"])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_df)
X_df_scaled = pd.DataFrame(X_scaled, columns=X_df.columns)

complete_df = pd.concat([X_df_scaled, y_df], axis=1)
complete_df
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1    0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2    0.196879    0.021231  1.109334          -0.268738   0.088358
# 3    1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4    0.295700    0.227694  1.840403           0.451946   1.281985
# ..        ...         ...       ...                ...        ...
# 173  0.876275    2.974543  0.305159           0.301803  -0.332922
# 174  0.493343    1.412609  0.414820           1.052516   0.158572
# 175  0.332758    1.744744 -0.389355           0.151661   1.422412
# 176  0.209232    0.227694  0.012732           0.151661   1.422412
# 177  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.808997    1.034819             -0.659563         1.224884
# ...

# %%
# # SPARSE DATA (including complete data) #
# features = [col for col in complete_df.columns if col != 'target']

# new_rows = []

# for index, row in complete_df.iterrows():
#     for r in range(1, max_remove_count): # more than one feature should be removed and more than one feature should be kept
#         for subset in itertools.combinations(features, r):
#             new_row = row.copy()
#             new_row[list(subset)] = 0
#             new_row['origin_index'] = index  # 원본 행의 인덱스를 저장
#             new_rows.append(new_row)

# new_rows_df = pd.concat(new_rows, axis=1).T

# sparse_df = pd.concat([complete_df, new_rows_df], ignore_index=True)
# sparse_df['origin_index'] = sparse_df['origin_index'].fillna(pd.Series(sparse_df.index))
# sparse_df[['target', 'origin_index']] = sparse_df[['target', 'origin_index']].astype(int)

# sparse_df

# %%
# SPARSE DATA (excluding complete data) #
features = [col for col in complete_df.columns if col != 'target']

new_rows = []

for index, row in complete_df.iterrows():
    for r in range(1, max_remove_count): # more than one feature should be removed and more than one feature should be kept
        for subset in itertools.combinations(features, r):
            new_row = row.copy()
            new_row[list(subset)] = 0
            new_row['origin_index'] = index  # 원본 행의 인덱스를 저장
            new_rows.append(new_row)

sparse_df = pd.concat(new_rows, ignore_index=True, axis=1).T
sparse_df['origin_index'] = sparse_df['origin_index'].fillna(pd.Series(sparse_df.index))
sparse_df[['target', 'origin_index']] = sparse_df[['target', 'origin_index']].astype(int)

sparse_df
# Out:
#        alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0     0.000000   -0.562250  0.232053          -1.169593   1.913905
# 1     1.518613    0.000000  0.232053          -1.169593   1.913905
# 2     1.518613   -0.562250  0.000000          -1.169593   1.913905
# 3     1.518613   -0.562250  0.232053           0.000000   1.913905
# 4     1.518613   -0.562250  0.232053          -1.169593   0.000000
# ...        ...         ...       ...                ...        ...
# 2309  1.395086    1.583165  1.365208           1.502943  -0.262708
# 2310  1.395086    1.583165  1.365208           1.502943  -0.262708
# 2311  1.395086    1.583165  1.365208           1.502943  -0.262708
# 2312  1.395086    1.583165  1.365208           1.502943  -0.262708
# 2313  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#       total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0          0.808997    1.034819             -0.659563         1.224884
# ...
